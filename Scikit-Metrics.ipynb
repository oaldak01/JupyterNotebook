# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

df = pd.read_csv("/Users/omaraldakheel/Downloads/creditcard.csv")[:80_000]
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
X = df.drop(columns=['Time', 'Amount', 'Class']).values # remove redundant data
y = df['Class'].values # val we want to predict

f"Shapes of X={X.shape} y={y.shape}, #Fraud Cases = {y.sum()}"
# Out:
# 'Shapes of X=(80000, 28) y=(80000,), #Fraud Cases = 196'

# %%
from sklearn.linear_model import LogisticRegression

mod = LogisticRegression(class_weight={0:1, 1:2}, max_iter = 1000)
mod.fit(X,y).predict(X).sum()
# Out:
# np.int64(172)

# %%
lr = LogisticRegression()
??lr.score # accuracy is the value being scored but it might not be what we need
# Out:
# Object `lr.score # accuracy is the value being scored but it might not be what we need` not found.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score, recall_score, make_scorer

def min_recall_precision(est, X, y_true, sample_weight=None):
    y_pred = est.predict(X)
    recall = recall_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    return min(recall, precision)

grid = GridSearchCV(
    estimator=LogisticRegression(max_iter=1000),
    param_grid={'class_weight': [{0: 1, 1: v} for v in np.linspace(1, 20, 30)]},
    scoring={'precision': make_scorer(precision_score),
            'recall': make_scorer(recall_score),
            'min_both': min_recall_precision},
    refit='min_both',
    return_train_score=True,
    cv=10,
    n_jobs=-1
)
grid.fit(X, y, sample_weight=np.log(1 + df['Amount']));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[123], line 21
#       8     return min(recall, precision)
#      10 grid = GridSearchCV(
#      11     estimator=LogisticRegression(max_iter=1000),
#      12     param_grid={'class_weight': [{0: 1, 1: v} for v in np.linspace(1, 20, 30)]},
#    (...)
#      19     n_jobs=-1
#      20 )
# ---> 21 grid.fit(X, y, sample_weight=np.log(1 + df['Amount']))
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.113977      0.015711         0.005001        0.001519
# 1        0.088000      0.025923         0.004536        0.003060
# 2        0.096723      0.013327         0.003943        0.001547
# 3        0.084946      0.014501         0.003586        0.001913
# 4        0.084895      0.011126         0.006793        0.006054
# 5        0.070698      0.010378         0.002432        0.000124
# 6        0.067111      0.007704         0.002423        0.000171
# 7        0.065648      0.007019         0.002564        0.000291
# 8        0.069135      0.008914         0.003215        0.002303
# 9        0.066448      0.007098         0.002830        0.000943
# 10       0.066205      0.006632         0.002810        0.000759
# 11       0.070028      0.006236         0.002530        0.000250
# 12       0.077589      0.017141         0.004351        0.002034
# ...

# %%
def min_recall_precision(y_true, y_pred):
    recall = recall_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    return min(recall,precision)

# %%
plt.figure(figsize=(12, 4))
df = pd.DataFrame(grid.cv_results_)
for score in ['mean_test_recall_score', 'mean_test_precision_score', 'mean_test_min_both']:
    plt.plot([_[1] for _ in df['param_class_weight']], 
        df[score],
        label=score)

plt.legend();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 2
#       1 plt.figure(figsize=(12, 4))
# ----> 2 df = pd.DataFrame(grid.cv_results_)
#       3 for score in ['mean_test_recall_score', 'mean_test_precision_score', 'mean_test_min_both']:
#       4     plt.plot([_[1] for _ in df['param_class_weight']],
#       5         df[score],
#       6         label=score)
#
# AttributeError: 'GridSearchCV' object has no attribute 'cv_results_'

# %%
s = make_scorer(min_recall_precision)
??s
# Out:
# Signature:       s(estimator, X, y_true, sample_weight=None, **kwargs)
# Type:            _Scorer
# String form:     make_scorer(min_recall_precision, response_method='predict')
# File:            /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_scorer.py
# Source:
# class _Scorer(_BaseScorer):
#     def _score(self, method_caller, estimator, X, y_true, **kwargs):
#         """Evaluate the response method of `estimator` on `X` and `y_true`.
#
#         Parameters
#         ----------
#         method_caller : callable
#             Returns predictions given an estimator, method name, and other
#             arguments, potentially caching results.
#
#         estimator : object
#             Trained estimator to use for scoring.
#
#         X : {array-like, sparse matrix}
#             Test data that will be fed to clf.decision_function or
#             clf.predict_proba.
#
#         y_true : array-like
# ...
